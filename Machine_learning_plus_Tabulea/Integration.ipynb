# %%
from Absent_model import*

# %%
model = absenteeism_model('model', 'scaler')

model.load_and_clean_data('Absenteeism_new_data.csv')

# Get the predicted DataFrame
predicted_df = model.predicted_outputs()

# Save to CSV
predicted_df.to_csv('Absenteeism_predictions.csv', index=False)

print("✅ Predictions saved to Absenteeism_predictions.csv")
# Out:
# ✅ Predictions saved to Absenteeism_predictions.csv
